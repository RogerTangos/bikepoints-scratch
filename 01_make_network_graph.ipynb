# %%
import copy
import urllib.request
import random
import folium
import xml.sax
from math import radians, cos, sin, asin, sqrt
from pathlib import Path
import networkx as nx

# %%
def haversine_distance(lon1, lat1, lon2, lat2, unit_m=True):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    default unit : km
    """
    # convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * asin(sqrt(a))
    r = 6371  # Radius of the Earth in kilometers. Use 3956 for miles
    if unit_m:
        r *= 1000
    return c * r


class Node(object):
    def __init__(self, id, lon, lat):
        self.id = id
        self.lon = lon
        self.lat = lat
        self.tags = {}

    def __str__(self):
        return "Node (id : %s) lon : %s, lat : %s "%(self.id, self.lon, self.lat)


class Way(object):
    def __init__(self, id, osm):
        self.osm = osm
        self.id = id
        self.nds = []
        self.tags = {}

    def split(self, dividers):
        # slice the node-array using this nifty recursive function
        def slice_array(ar, dividers):
            for i in range(1,len(ar)-1):
                if dividers[ar[i]]>1:
                    left = ar[:i+1]
                    right = ar[i:]

                    rightsliced = slice_array(right, dividers)

                    return [left]+rightsliced
            return [ar]

        slices = slice_array(self.nds, dividers)

        # create a way object for each node-array slice
        ret = []
        i = 0
        for slice in slices:
            littleway = copy.copy(self)
            littleway.id += "-%d" % i
            littleway.nds = slice
            ret.append(littleway)
            i += 1

        return ret

# %%
class OSM(object):
    def __init__(self, osm_xml_data, is_xml_string=True):
        """ File can be either a filename or stream/file object.

        set `is_xml_string=False` if osm_xml_data is a filename or a file stream.
        """
        nodes = {}
        ways = {}

        superself = self

        class OSMHandler(xml.sax.ContentHandler):
            @classmethod
            def setDocumentLocator(self, loc):
                pass

            @classmethod
            def startDocument(self):
                pass

            @classmethod
            def endDocument(self):
                pass

            @classmethod
            def startElement(self, name, attrs):
                if name == 'node':
                    self.currElem = Node(attrs['id'], float(attrs['lon']), float(attrs['lat']))
                elif name == 'way':
                    self.currElem = Way(attrs['id'], superself)
                elif name == 'tag':
                    self.currElem.tags[attrs['k']] = attrs['v']
                elif name == 'nd':
                    self.currElem.nds.append(attrs['ref'])

            @classmethod
            def endElement(self, name):
                if name == 'node':
                    nodes[self.currElem.id] = self.currElem
                elif name == 'way':
                    ways[self.currElem.id] = self.currElem

            @classmethod
            def characters(self, chars):
                pass

        if is_xml_string:
            xml.sax.parseString(osm_xml_data, OSMHandler)
        else:
            with open(osm_xml_data, mode='r') as f:
                xml.sax.parse(f, OSMHandler)

        self.nodes = nodes
        self.ways = ways

        # count times each node is used
        node_histogram = dict.fromkeys(self.nodes.keys(), 0)
        for way in self.ways.values():
            if len(way.nds) < 2:  # if a way has only one node, delete it out of the osm collection
                del self.ways[way.id]
            else:
                for node in way.nds:
                    node_histogram[node] += 1

        # use that histogram to split all ways, replacing the member set of ways
        new_ways = {}
        for id, way in self.ways.items():
            split_ways = way.split(node_histogram)
            for split_way in split_ways:
                new_ways[split_way.id] = split_way
        self.ways = new_ways

# %%
def read_osm(osm_xml_data, is_xml_string=True, only_roads=True):
    """Read graph in OSM format from file specified by name or by stream object.
    Parameters
    ----------
    filename_or_stream : filename or stream object

    Returns
    -------
    G : Graph

    Examples
    --------
    >>> G=nx.read_osm(nx.download_osm(-122.33,47.60,-122.31,47.61))
    >>> import matplotlib.pyplot as plt
    >>> plt.plot([G.node[n]['lat']for n in G], [G.node[n]['lon'] for n in G], 'o', color='k')
    >>> plt.show()
    """
    osm = OSM(osm_xml_data, is_xml_string=is_xml_string)
    G = nx.DiGraph()

    ## Add ways
    for w in osm.ways.values():
        if only_roads and 'highway' not in w.tags:
            continue
          
        if ('oneway' in w.tags):
            if (w.tags['oneway'] == 'yes'):
                # ONLY ONE DIRECTION
                nx.add_path(G, w.nds, id=w.id, tags=w.tags)
            else:
                # BOTH DIRECTION
                nx.add_path(G, w.nds, id=w.id, tags=w.tags)
                nx.add_path(G, w.nds[::-1], id=w.id, tags=w.tags)
        else:
            # BOTH DIRECTION
            nx.add_path(G, w.nds, id=w.id, tags=w.tags)
            nx.add_path(G, w.nds[::-1], id=w.id, tags=w.tags)

    # Complete the used nodes' information
    coordinates_map = {}
    for n_id in G.nodes():
        n = osm.nodes[n_id]
        G.nodes[n_id]['lat'] = n.lat
        G.nodes[n_id]['lon'] = n.lon
        G.nodes[n_id]['id'] = n.id
        G.nodes[n_id]['tags'] = n.tags
        coordinates_map[n_id] = (n.lon, n.lat)

    # Estimate the length of each way
    for u, v, d in G.edges(data=True):
        distance = haversine_distance(G.nodes[u]['lon'], G.nodes[u]['lat'], G.nodes[v]['lon'], G.nodes[v]['lat'], unit_m=True)  # Give a realistic distance estimation (neither EPSG nor projection nor reference system are specified)

        G.add_weighted_edges_from([(u, v, distance)], weight='havlen')

    G = nx.relabel_nodes(G, coordinates_map)
    return G

# %%
g = read_osm("./cambridge-small.osm", is_xml_string=False)

# %%
len(g.nodes)
# Out:
# 346

# %% [markdown]
# # Write to Disk

# %%
nx.write_gpickle(g, "01_cambridge-small.gpickle")

# %% [markdown]
# # Cruft

# %% [markdown]
# ## Dictionary of Tags

# %%
tags = {}
osm = OSM('./cambridge.xml', is_xml_string=False)

for w in osm.ways.values():
    for t in w.tags:
        if tags.get(t):
            tags[t] = tags[t] + 1
        else:
            tags[t] = 1

# %%
tags
# Out:
# {'attribution': 3748,
#  'condition': 3384,
#  'highway': 11575,
#  'lanes': 3630,
#  'massgis:way_id': 3657,
#  'maxspeed': 2866,
#  'name': 9052,
#  'source': 7686,
#  'surface': 5426,
#  'width': 4305,
#  'alt_name': 885,
#  'loc_name': 34,
#  'oneway': 2658,
#  'ref': 1090,
#  'bicycle': 1534,
#  'cycleway:right': 339,
#  'maxspeed:type': 224,
#  'cycleway': 846,
#  'massgis:ref': 475,
#  'source:maxspeed': 63,
#  'busway:right': 4,
#  'hgv': 240,
#  'lit': 1608,
#  'sidewalk': 358,
#  'source:hgv': 5,
#  'cycleway:both': 272,
#  'lanes:forward': 189,
#  'turn:lanes:forward': 130,
#  'service': 720,
#  'official_name': 62,
#  'old_ref': 34,
#  'parking:lane:right': 54,
#  'turn:lanes': 99,
#  'foot': 1595,
#  'horse': 713,
#  'motor_vehicle': 1054,
#  'access': 2372,
#  'lanes:backward': 150,
#  'incline': 789,
#  'junction': 6,
#  'note': 182,
#  'NHS': 64,
#  'turn:lanes:backward': 43,
#  'parking:lane:both': 52,
#  'parking:lane:left': 63,
#  'parking:condition:right': 28,
#  'note:lanes': 3,
#  'start_date': 953,
#  'name:mk': 66,
#  'oneway:bicycle': 18,
#  'old_name': 30,
#  'cycleway:left': 57,
#  'hazmat': 235,
#  'bridge': 580,
#  'layer': 991,
#  'bus': 19,
#  'psv': 14,
#  'FIXME:hgv': 44,
#  'covered': 961,
#  'maxheight': 89,
#  'tunnel': 50,
#  'created_by': 38,
#  'destination': 54,
#  'destination:ref': 21,
#  'destination:street': 8,
#  'toll': 84,
#  'orig_name': 58,
#  'destination:ref:to': 4,
#  'junction:ref': 3,
#  'wikidata': 1756,
#  'wikipedia': 1618,
#  'maxspeed:advisory': 1,
#  'coach': 4,
#  'goods': 4,
#  'hgv_articulated': 4,
#  'lhv': 4,
#  'destination:symbol': 1,
#  'construction': 75,
#  'fixme': 6,
#  'website': 1895,
#  'dog': 828,
#  'stroller': 541,
#  'electrified': 223,
#  'frequency': 56,
#  'gauge': 317,
#  'massgis:geom_id': 12,
#  'operator': 1212,
#  'railway': 404,
#  'voltage': 57,
#  'ramp': 8,
#  'noname': 5,
#  'level': 128,
#  'comment': 6,
#  'ele': 583,
#  'gnis:county_id': 147,
#  'gnis:created': 146,
#  'gnis:feature_id': 579,
#  'gnis:state_id': 150,
#  'leisure': 1598,
#  'addr:city': 2007,
#  'addr:housename': 405,
#  'addr:housenumber': 8514,
#  'addr:postcode': 1905,
#  'addr:state': 1999,
#  'addr:street': 8054,
#  'building': 11292,
#  'campusbuilding': 601,
#  'area': 929,
#  'landuse': 2939,
#  'natural': 1063,
#  'architect': 637,
#  'building:levels': 1972,
#  'building:material': 584,
#  'roof:shape': 257,
#  'height': 896,
#  'wheelchair': 681,
#  'roof:material': 114,
#  'amenity': 1105,
#  'gnis:county_name': 397,
#  'gnis:import_uuid': 380,
#  'gnis:reviewed': 341,
#  'designation': 18,
#  'denomination': 38,
#  'religion': 67,
#  'short_name': 24,
#  'description': 53,
#  'footway': 3272,
#  'smoothness': 228,
#  'gnis:county': 4,
#  'sport': 193,
#  'boat': 187,
#  'boat:parts': 43,
#  'boat:repair': 43,
#  'colour': 390,
#  'motorboat': 171,
#  'phone': 622,
#  'roof:colour': 322,
#  'roof:levels': 48,
#  'building:height': 8,
#  'location': 131,
#  'tactile_paving': 477,
#  'maxweight': 272,
#  'source_ref': 64,
#  'historic': 146,
#  'memorial': 94,
#  'addr:country': 29,
#  'tdd': 1,
#  'tourism': 99,
#  'addr:place': 2,
#  'other_source': 9,
#  'opening_hours': 328,
#  'shop': 73,
#  'addr:unit': 26,
#  'atm': 2,
#  'brand': 63,
#  'apartments': 35,
#  'cuisine': 29,
#  'fee': 73,
#  'parking': 152,
#  'building:flats': 1,
#  'office': 33,
#  'note:source': 44,
#  'brand:wikidata': 62,
#  'brand:wikipedia': 62,
#  'opening_hours:storage': 1,
#  'image': 1,
#  'building:levels:underground': 1,
#  'man_made': 976,
#  'dispensing': 10,
#  'drive_through': 13,
#  'healthcare': 19,
#  'payment:cash': 11,
#  'payment:visa': 11,
#  'year_of_construction': 21,
#  'toilets:disposal': 5,
#  'toilets:handwashing': 5,
#  'unisex': 5,
#  'name:tr': 4,
#  'owner': 1324,
#  'heritage': 4,
#  'email': 310,
#  'bench': 25,
#  'bin': 17,
#  'shelter_type': 25,
#  'smoking': 36,
#  'power': 143,
#  'substation': 10,
#  'material': 1054,
#  'fax': 1,
#  'contact:phone': 10,
#  'region': 14,
#  'type': 22,
#  'levels': 2,
#  'internet_access': 28,
#  'internet_access:fee': 27,
#  'internet_access:ssid': 2,
#  'ref:isil': 2,
#  'telecom': 5,
#  'name:zh': 5,
#  'toilets:wheelchair': 2,
#  'massgis:ARTICLE97': 1070,
#  'massgis:ASSESS_ACR': 1070,
#  'massgis:ATT_DATE': 1070,
#  'massgis:DCAM_ID': 1068,
#  'massgis:DEED_ACRES': 1070,
#  'massgis:EOEAINVOLV': 1068,
#  'massgis:FEESYM': 1070,
#  'massgis:FEE_OWNER': 1070,
#  'massgis:FY_FUNDING': 1068,
#  'massgis:LEV_PROT': 1070,
#  'massgis:OS_DEED_BO': 1068,
#  'massgis:OS_DEED_PA': 1068,
#  'massgis:OS_ID': 1070,
#  'massgis:OWNER_ABRV': 1068,
#  'massgis:OWNER_TYPE': 1070,
#  'massgis:POLY_ID': 1070,
#  'massgis:PRIM_PURP': 1070,
#  'massgis:PUB_ACCESS': 1070,
#  'massgis:SITE_NAME': 1065,
#  'massgis:SOURCE_MAP': 391,
#  'massgis:TOWN_ID': 1070,
#  'ownership': 1098,
#  'protected': 1415,
#  'grades': 1,
#  'massgis:school_id': 33,
#  'source:url': 28,
#  'source:addr': 1,
#  'delivery': 7,
#  'takeaway': 7,
#  'baby_hatch': 2,
#  'name:el': 4,
#  'gay': 4,
#  'lgbtq': 4,
#  'postal_code': 4,
#  'massgis:MANAGER': 336,
#  'massgis:MANAGR_ABR': 336,
#  'massgis:MANAGR_TYP': 336,
#  'massgis:GRANTPROG1': 309,
#  'massgis:GRANTTYPE1': 309,
#  'massgis:PROJ_ID1': 967,
#  'seamark:type': 358,
#  'massgis:CAL_DATE_R': 34,
#  'massgis:COMMENTS': 258,
#  'service_times': 1,
#  'building_1': 2,
#  'rooms': 15,
#  'outdoor_seating': 8,
#  'healthcare:speciality': 2,
#  'historical': 12,
#  'contact:email': 11,
#  'contact:website': 8,
#  'max_age': 28,
#  'min_age': 37,
#  'opening_hours:covid19': 8,
#  'playground:theme': 28,
#  'service:vehicle:car_repair': 2,
#  'service:vehicle:oil_change': 1,
#  'massgis:ASSESS_BLK': 1,
#  'massgis:ASSESS_LOT': 25,
#  'massgis:ASSESS_MAP': 25,
#  'massgis:SOURCE_TYP': 1,
#  'isced:level': 27,
#  'building:units': 1,
#  'air_conditioning': 3,
#  'payment:apple_pay': 3,
#  'toilets': 5,
#  'toilets:access': 5,
#  'second_hand': 1,
#  'building:colour': 107,
#  'alt_name:ko': 5,
#  'name:en': 8,
#  'name:ko': 8,
#  'name:zh-Hans': 8,
#  'name:zh-Hant': 8,
#  'payment:mastercard': 5,
#  'capacity': 104,
#  'maxstay': 14,
#  'park_ride': 14,
#  'supervised': 43,
#  'artwork_type': 5,
#  'capacity:disabled': 4,
#  'barrier': 821,
#  'old_railway_operator': 54,
#  'usage': 64,
#  'name:ar': 24,
#  'tracktype': 34,
#  'handrail': 36,
#  'indoor': 107,
#  'step_count': 26,
#  'fence_type': 307,
#  'note:old_railway_operator': 10,
#  'railway:traffic_mode': 48,
#  'crossing': 485,
#  'proposed_name': 2,
#  'backrest': 11,
#  'ramp:wheelchair': 3,
#  'fishing': 341,
#  'floating': 155,
#  'building:part': 638,
#  'massgis:GRANTPROG2': 233,
#  'massgis:GRANTTYPE2': 233,
#  'massgis:PROJ_ID2': 233,
#  'bridge:structure': 320,
#  'bridge_ref': 99,
#  'segregated': 133,
#  'water': 850,
#  'jurisdiction': 21,
#  'power_supply': 9,
#  'landcover': 27,
#  'operator:type': 21,
#  'network': 8,
#  'public_transport': 13,
#  'subway': 8,
#  'generator:method': 95,
#  'generator:output:electricity': 96,
#  'generator:source': 95,
#  'aerialway': 5,
#  'club': 4,
#  'architect:wikidata': 27,
#  'capacity:boats': 27,
#  'contact:facebook': 30,
#  'contact:instagram': 30,
#  'contact:twitter': 30,
#  'crossing:island': 181,
#  'artist_name': 1,
#  'boundary': 397,
#  'mooring': 11,
#  'emergency': 14,
#  'emergency_room': 4,
#  'name:etymology:wikidata': 1,
#  'protect_class': 385,
#  'hov': 3,
#  'wall': 206,
#  'traffic_calming': 5,
#  'cables': 32,
#  'circuits': 32,
#  'traffic_signals': 92,
#  'building:architecture': 97,
#  'heritage:website': 5,
#  'disused:amenity': 3,
#  'disused:name': 3,
#  'hoops': 19,
#  'bridge:movable': 61,
#  'bridge:ref': 150,
#  'bridge:type': 19,
#  'length': 25,
#  'length_unit': 19,
#  'building:roof:shape': 1,
#  'seasonal': 1,
#  'private': 4,
#  'admin_level': 6,
#  'border_type': 5,
#  'name:he': 10,
#  'name:uk': 10,
#  'waterway': 11,
#  'social_facility': 2,
#  'social_facility:for': 2,
#  'weather_protection': 1,
#  'bicycle_parking': 14,
#  'former:name': 1,
#  'residential': 2,
#  'playground': 2,
#  'parking:condition:right:maxstay': 1,
#  'surveillance:type': 1,
#  'informal': 5,
#  'trail_visibility': 5,
#  'fountain': 8,
#  'artist:wikidata': 11,
#  'wikimedia_commons': 28,
#  'sanitary_dump_station': 8,
#  'intermittent': 129,
#  'lock': 1,
#  'historic:landuse': 1,
#  'proposed:railway': 1,
#  'tower:construction': 6,
#  'tower:type': 6,
#  'bridge:support': 16,
#  'addr2:housenumber': 8,
#  'construction:building:levels': 20,
#  'leaf_cycle': 30,
#  'leaf_type': 226,
#  'species:wikidata': 30,
#  'species:wikipedia': 30,
#  'seats': 6,
#  'canoe': 128,
#  'ice_skates': 128,
#  'kayak': 128,
#  'maxwidth': 128,
#  'sailboat': 128,
#  'salt': 169,
#  'tidal': 169,
#  'drinking_water': 7,
#  'substance': 2,
#  'check_date': 9,
#  'parking_space': 34,
#  'wetland': 106,
#  'MassDCR:ResearchAccessPermitNumber': 23,
#  'MassDEP:FileNumber': 23,
#  'garden:type': 58,
#  'source:heritage': 12,
#  'building:min_level': 1,
#  'building:roof': 1,
#  'direction': 82,
#  'inscription': 82,
#  'design:ref': 92,
#  'min_height': 6,
#  'bollard': 1,
#  'door': 4,
#  'lockable': 4,
#  'restriction': 3,
#  'name:et': 3,
#  'manager': 3,
#  'route': 3,
#  'FIXME': 3,
#  'is_in:state': 3,
#  'symbol': 3,
#  'public_transport:version': 3,
#  'from': 3,
#  'passenger': 3,
#  'to': 3,
#  'alt_ref': 3,
#  'cycle_network': 3,
#  'nist:fips_code': 3,
#  'nist:state_fips': 3,
#  'population': 3,
#  'source:population': 3,
#  'addr:county': 3,
#  'place': 3,
#  'area:highway': 3,
#  'name:eo': 3,
#  'name:hak': 3,
#  'name:ja': 3,
#  'name:nan': 3,
#  'name:oc': 3,
#  'name:pl': 3,
#  'name:ru': 3,
#  'name:ta': 3,
#  'site': 3,
#  'name:az': 3,
#  'name:ba': 3,
#  'name:be': 3,
#  'name:bg': 3,
#  'name:bn': 3,
#  'name:br': 3,
#  'name:ca': 3,
#  'name:cs': 3,
#  'name:cv': 3,
#  'name:cy': 3,
#  'name:da': 3,
#  'name:es': 3,
#  'name:eu': 3,
#  'name:fa': 3,
#  'name:fi': 3,
#  'name:fr': 3,
#  'name:ga': 3,
#  'name:gd': 3,
#  'name:gl': 3,
#  'name:hi': 3,
#  'name:hr': 3,
#  'name:hu': 3,
#  'name:hy': 3,
#  'name:id': 3,
#  'name:is': 3,
#  'name:it': 3,
#  'name:jv': 3,
#  'name:ka': 3,
#  'name:kk': 3,
#  'name:kn': 3,
#  'name:ku': 3,
#  'name:la': 3,
#  'name:lb': 3,
#  'name:lt': 3,
#  'name:lv': 3,
#  'name:mr': 3,
#  'name:ms': 3,
#  'name:my': 3,
#  'name:nl': 3,
#  'name:pt': 3,
#  'name:qu': 3,
#  'name:ro': 3,
#  'name:sa': 3,
#  'name:sl': 3,
#  'name:sq': 3,
#  'name:sr': 3,
#  'name:sw': 3,
#  'name:te': 3,
#  'name:th': 3,
#  'name:tt': 3,
#  'name:ug': 3,
#  'name:ur': 3,
#  'name:vi': 3,
#  'name:yi': 3,
#  'name:yo': 3,
#  'brand:website': 3,
#  'payment:credit_cards': 3,
#  'payment:debit_cards': 3,
#  'payment:mobile_app': 3,
#  'via': 3,
#  'day_off': 3,
#  'day_on': 3,
#  'hour_off': 3,
#  'hour_on': 3,
#  'route_master': 3,
#  'implicit': 3,
#  'restriction:hgv': 3,
#  'network:wikidata': 3,
#  'roof:height': 3,
#  'restriction:conditional': 3}

# %% [markdown]
# ## Voterrank (just for PoC)

# %%
m = folium.Map(location = [42.374253,-71.0938267], zoom_start=13)
nodes_subset = networkx.algorithms.centrality.voterank(g, number_of_nodes=10)

for node in nodes_subset:
    lon,lat = node
    m.add_child(folium.Marker(location=[lat,lon],popup=node_id))
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Betweenness centrality

# %%
m = folium.Map(location = [42.374253,-71.0938267], zoom_start=13)
nodes_subset = networkx.algorithms.centrality.betweenness_centrality(g)

for lon_lat in nodes_subset:
    if nodes_subset.get(lon_lat, 0) > .2:
        lon,lat = lon_lat
        m.add_child(folium.Marker(location=[lat,lon]))
        
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Map with PolyLine (just because)

# %%
m = folium.Map(location = [42.374253,-71.0938267], zoom_start=13)
nodes_subset = random.sample(g.nodes.data(), 10)
node_walk = []

for node in nodes_subset:
    node_id = node[1]["id"]
    lon_lat = node[0]
    lon,lat = lon_lat

    #For each node, add a marker on the map
    m.add_child(folium.Marker(location=[lat,lon],popup=node_id))

    #For each node, add it as a destination on the PolyLine walk.
    #To really have a realistic route (i.e. not "as the crow flies") you'd need 
    # as many intermediary steps as possible if you were doing it just with points.
    # But I'm sure it can take GIS edge information too--haven't looked at the edge data
    node_walk.append([lat,lon])

import pdb; pdb.set_trace()

m.add_child(folium.PolyLine(locations = node_walk[:3], line_opacity = 0.5, color="blue"))
m.add_child(folium.PolyLine(locations = node_walk[5:], line_opacity = 0.5, color="red"))


m
# Out:
# --Return--
# None
# > <ipython-input-11-cb79bbdced4d>(19)<module>()
#      17     node_walk.append([lat,lon])
#      18
# ---> 19 import pdb; pdb.set_trace()
#      20
#      21 m.add_child(folium.PolyLine(locations = node_walk[:3], line_opacity = 0.5, color="blue"))
#
# ipdb> node_walk
# [[42.361681, -71.1153504], [42.362279, -71.107591], [42.3612002, -71.1076295], [42.3599749, -71.1052898], [42.3614322, -71.1080763], [42.360584, -71.10711], [42.3611601, -71.1077133], [42.3613684, -71.1075341], [42.3611108, -71.1079923], [42.3580203, -71.1142064]]
# ipdb> node_walk[:3]
# [[42.361681, -71.1153504], [42.362279, -71.107591], [42.3612002, -71.1076295]]
# ipdb> node_walk[5:]
# [[42.360584, -71.10711], [42.3611601, -71.1077133], [42.3613684, -71.1075341], [42.3611108, -71.1079923], [42.3580203, -71.1142064]]
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-11-cb79bbdced4d> in <module>
#      17     node_walk.append([lat,lon])
#      18
# ---> 19 import pdb; pdb.set_trace()
#      20
#      21 m.add_child(folium.PolyLine(locations = node_walk[:3], line_opacity = 0.5, color="blue"))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
#      94             return self.dispatch_exception(frame, arg)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py in dispatch_return(self, frame, arg)
#     152             finally:
#     153                 self.frame_returning = None
# --> 154             if self.quitting: raise BdbQuit
#     155             # The user issued a 'next' or 'until' command.
#     156             if self.stopframe is frame and self.stoplineno != -1:
#
# BdbQuit:
