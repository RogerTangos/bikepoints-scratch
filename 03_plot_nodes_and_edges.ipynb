# %%
import random
import networkx as nx
import folium as f

from vars import DATASET
print(DATASET)
# Out:
# cambridge-small

# %%
g = nx.read_gpickle("./data/02_" + DATASET + ".gpickle")

# %% [markdown]
# # Map

# %%
g.edges(('61322871', '621117424'))
# Out:
# OutEdgeDataView([('61322871', '621117424'), ('61322871', '61326958'), ('61322871', '61326981'), ('621117424', '61322877')])

# %%
g.nodes()['61322871']['lat']
# Out:
# 42.361427

# %%
m = f.Map(location = [42.3611108,-71.1079923], zoom_start=16)
nodes_data_subset = g.nodes().data()

for edge in g.edges():
    start_id = edge[0]
    end_id = edge[1]
    
    lat0, lon0 = g.nodes()[start_id]['lat'], g.nodes()[start_id]['lon']
    lat1, lon1 = g.nodes()[end_id]['lat'], g.nodes()[end_id]['lon']
    
    edge = [[lat0, lon0], [lat1, lon1]]
    
    m.add_child(f.PolyLine(locations=edge, line_opacity=0.1, color="gray"))
        
# add nodes to graph
for node_data in nodes_data_subset:
  
    node_id = node_data[1]["id"]
    lon,lat = node_data[1]['lon'], node_data[1]['lat']  
    
    m.add_child(f.Marker(location=[lat,lon],popup=node_id))
    
    
#     if node_data[1].get('weird') and g.degree()[node_id] != 2:
#         m.add_child(f.CircleMarker(location=[lat,lon], color='blue', radius=2))    
#     if node_data[1].get('k_1_0'):
#         m.add_child(f.CircleMarker(location=[lat,lon], color='gray', radius=2))
#     if node_data[1].get('k_2'):
#         m.add_child(f.CircleMarker(location=[lat,lon], color='red', radius=4))
#     if node_data[1].get('k_2_1'):
#         m.add_child(f.CircleMarker(location=[lat,lon], color='blue', radius=6))
#     if node_data[1].get('k_2_2'):
#         m.add_child(f.CircleMarker(location=[lat,lon], color='orange', radius=8))
#     if node_data[1].get('k_3_0'):
#         m.add_child(f.CircleMarker(location=[lat,lon], color='cyan', radius=10))
        
        
    
#     voterank = node_data[1].get('voterank')
#     betweenness = node_data[1].get('betweenness')

#     if 
    
    
#     # distinguish between betweenness, voterank, and non-central nodes
#     if betweenness:
# #         m.add_child(f.Marker(location=[lat,lon],popup=node_id))
#         m.add_child(f.CircleMarker(location=[lat, lon], popup=node_id, color="blue", radius=5))
#     elif voterank:
#         m.add_child(f.CircleMarker(location=[lat, lon], popup=node_id, color="red", radius=4))
#     else:
#         m.add_child(f.CircleMarker(location=[lat, lon], popup=node_id, color="gray", radius=2, opacity=0.2))
    
        
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Experiment

# %%
sample_node_data = list(g.nodes().data())[0]
sample_node = sample_node_data[0]

# %%
neighbors = list(g.neighbors(sample_node))
neighbors
# Out:
# [(-71.1079923, 42.3611108),
#  (-71.1084222, 42.3614165),
#  (-71.108166, 42.361766),
#  (-71.108719, 42.361241)]
